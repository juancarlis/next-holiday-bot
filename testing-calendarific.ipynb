# %%
# importing libraries
import pandas as pd
import requests
import datetime
import json
from config import Config

# %%
# initialize state variables
country = 'AR'
this_year = datetime.datetime.now().year
next_year = this_year + 1
today = datetime.date.today()
API_KEY = Config().API_KEY

# %%
# requesting data from API
response_this_yr = requests.get(f'https://calendarific.com/api/v2/holidays?&api_key={API_KEY}&country={country}&year={this_year}')
data_this_yr = json.loads(response_this_yr.text)

response_next_yr = requests.get(f'https://calendarific.com/api/v2/holidays?&api_key={API_KEY}&country={country}&year={next_year}')
data_next_yr = json.loads(response_next_yr.text)

# %%
# cleaning data so as to create a Pandas DataFrame
clean_data_this_yr = data_this_yr['response']['holidays']
clean_data_next_yr = data_next_yr['response']['holidays']

# %%
# creating Pandas DataFrame
df_this_year = pd.DataFrame.from_dict(clean_data_this_yr)
df_next_year = pd.DataFrame.from_dict(clean_data_next_yr)

df = pd.concat([df_this_year, df_next_year], axis=0)

# %%
# indexing new dataframe
df.reset_index(inplace=True)

# %%
df
# Out:
#     index                                name  \
# 0       0                      New Year's Day
# 1       1            Carnival / Shrove Monday
# 2       2           Carnival / Shrove Tuesday
# 3       3                       March Equinox
# 4       4                        Memorial Day
# ..    ...                                 ...
# 75     33            National Sovereignty Day
# 76     34  Feast of the Immaculate Conception
# 77     35                   December Solstice
# 78     36                       Christmas Day
# 79     37                      New Year's Eve
#
#                                           description  \
# 0   New Year’s Day is the first day of the year, o...
# 1   Carnival / Shrove Monday is a national holiday...
# 2   Shrove Tuesday is a religious holiday that is ...
# 3           March Equinox in Argentina (Buenos Aires)
# 4     Memorial Day is a national holiday in Argentina
# ..                                                ...
# 75  National Sovereignty Day is a national holiday...
# 76  The Feast of the Immaculate Conception is a Ch...
# 77      December Solstice in Argentina (Buenos Aires)
# 78  Christmas Day is one of the biggest Christian ...
# 79  New Year’s Eve is the last day of the year, De...
#
#                               country  \
# 0   {'id': 'ar', 'name': 'Argentina'}
# 1   {'id': 'ar', 'name': 'Argentina'}
# 2   {'id': 'ar', 'name': 'Argentina'}
# 3   {'id': 'ar', 'name': 'Argentina'}
# 4   {'id': 'ar', 'name': 'Argentina'}
# ..                                ...
# 75  {'id': 'ar', 'name': 'Argentina'}
# 76  {'id': 'ar', 'name': 'Argentina'}
# 77  {'id': 'ar', 'name': 'Argentina'}
# 78  {'id': 'ar', 'name': 'Argentina'}
# 79  {'id': 'ar', 'name': 'Argentina'}
#
#                                                  date  \
# 0   {'iso': '2021-01-01', 'datetime': {'year': 202...
# 1   {'iso': '2021-02-15', 'datetime': {'year': 202...
# 2   {'iso': '2021-02-16', 'datetime': {'year': 202...
# 3   {'iso': '2021-03-20T06:37:31-03:00', 'datetime...
# 4   {'iso': '2021-03-24', 'datetime': {'year': 202...
# ..                                                ...
# 75  {'iso': '2022-11-21', 'datetime': {'year': 202...
# 76  {'iso': '2022-12-08', 'datetime': {'year': 202...
# 77  {'iso': '2022-12-21T18:48:13-03:00', 'datetime...
# 78  {'iso': '2022-12-25', 'datetime': {'year': 202...
# 79  {'iso': '2022-12-31', 'datetime': {'year': 202...
#
#                              type locations states
# 0              [National holiday]       All    All
# 1              [National holiday]       All    All
# 2              [National holiday]       All    All
# 3                        [Season]       All    All
# 4              [National holiday]       All    All
# ..                            ...       ...    ...
# 75             [National holiday]       All    All
# 76             [National holiday]       All    All
# 77                       [Season]       All    All
# 78  [National holiday, Christian]       All    All
# 79                   [Observance]       All    All
#
# [80 rows x 8 columns]

# %%
df.loc[0, 'date']['datetime']
# Out:
# {'year': 2021, 'month': 1, 'day': 1}

# %%
# formatting country and date columns
df['country'] = df['country'].apply(lambda x: x['name'])
df['date'] = df['date'].apply(lambda x: pd.Timestamp(
                year=x['datetime']['year'],
                month=x['datetime']['month'],
                day=x['datetime']['day']))

# %%
## for testing

df_test = df.copy()

# %%
df_test['type'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas/_libs/hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [National holiday]               31
# [Hebrew, Optional holiday]       10
# [Observance]                      9
# [Season]                          8
# [National holiday, Christian]     6
# [Muslim, Optional holiday]        6
# [Optional holiday]                4
# [Hebrew]                          4
# [Observance, Christian]           2
# Name: type, dtype: int64

# %%
df_test['type'] = df_test['type'].apply(lambda x: ','.join(x))

# %%
df_test['type'].value_counts()
# Out:
# National holiday              31
# Hebrew,Optional holiday       10
# Observance                     9
# Season                         8
# National holiday,Christian     6
# Muslim,Optional holiday        6
# Hebrew                         4
# Optional holiday               4
# Observance,Christian           2
# Name: type, dtype: int64

# %%
df_test.loc[df_test['type'] == 'National holiday' ,:]
# Out:
#     index                                               name  \
# 0       0                                     New Year's Day
# 1       1                           Carnival / Shrove Monday
# 2       2                          Carnival / Shrove Tuesday
# 4       4                                       Memorial Day
# 10     10                                Day of the Veterans
# 16     16                                Labor Day / May Day
# 18     18                              Bridge Public Holiday
# 19     19                   National Day/May 1810 Revolution
# 21     21                                           Flag Day
# 22     22  Day off for the Commemoration of General Don M...
# 24     24                                   Independence day
# 27     27                                     San Martín Day
# 34     34                              Bridge Public Holiday
# 35     35              Day of respect for cultural diversity
# 36     36                           National Sovereignty Day
# 37     37                              Bridge Public Holiday
# 38     38                 Feast of the Immaculate Conception
# 42      0                                     New Year's Day
# 43      1                           Carnival / Shrove Monday
# 44      2                          Carnival / Shrove Tuesday
# 46      4                                       Memorial Day
# 47      5                                Day of the Veterans
# 58     16                                Labor Day / May Day
# 60     18                   National Day/May 1810 Revolution
# 61     19  Commemoration of General Don Martín Miguel de ...
# 62     20                                           Flag Day
# 64     22                                   Independence day
# 67     25                                     San Martín Day
# 74     32              Day of respect for cultural diversity
# 75     33                           National Sovereignty Day
# 76     34                 Feast of the Immaculate Conception
#
#                                           description    country       date  \
# 0   New Year’s Day is the first day of the year, o...  Argentina 2021-01-01
# 1   Carnival / Shrove Monday is a national holiday...  Argentina 2021-02-15
# 2   Shrove Tuesday is a religious holiday that is ...  Argentina 2021-02-16
# 4     Memorial Day is a national holiday in Argentina  Argentina 2021-03-24
# 10  Day of the Veterans is a national holiday in A...  Argentina 2021-04-02
# 16  Labor Day, or May Day, is a day off for worker...  Argentina 2021-05-01
# 18  Bridge Public Holiday is a national holiday in...  Argentina 2021-05-24
# 19  National Day/May 1810 Revolution is a national...  Argentina 2021-05-25
# 21        Flag Day is a national holiday in Argentina  Argentina 2021-06-20
# 22  Day off for the Commemoration of General Don M...  Argentina 2021-06-21
# 24  Independence day is a national holiday in Arge...  Argentina 2021-07-09
# 27  San Martín Day is a national holiday in Argentina  Argentina 2021-08-16
# 34  Bridge Public Holiday is a national holiday in...  Argentina 2021-10-08
# 35  Day of respect for cultural diversity is a nat...  Argentina 2021-10-11
# 36  National Sovereignty Day is a national holiday...  Argentina 2021-11-20
# 37  Bridge Public Holiday is a national holiday in...  Argentina 2021-11-22
# 38  The Feast of the Immaculate Conception is a Ch...  Argentina 2021-12-08
# 42  New Year’s Day is the first day of the year, o...  Argentina 2022-01-01
# 43  Carnival / Shrove Monday is a national holiday...  Argentina 2022-02-28
# 44  Shrove Tuesday is a religious holiday that is ...  Argentina 2022-03-01
# 46    Memorial Day is a national holiday in Argentina  Argentina 2022-03-24
# 47  Day of the Veterans is a national holiday in A...  Argentina 2022-04-02
# 58  Labor Day, or May Day, is a day off for worker...  Argentina 2022-05-01
# 60  National Day/May 1810 Revolution is a national...  Argentina 2022-05-25
# 61  Commemoration of General Don Martín Miguel de ...  Argentina 2022-06-17
# 62        Flag Day is a national holiday in Argentina  Argentina 2022-06-20
# 64  Independence day is a national holiday in Arge...  Argentina 2022-07-09
# 67  San Martín Day is a national holiday in Argentina  Argentina 2022-08-15
# 74  Day of respect for cultural diversity is a nat...  Argentina 2022-10-10
# 75  National Sovereignty Day is a national holiday...  Argentina 2022-11-21
# 76  The Feast of the Immaculate Conception is a Ch...  Argentina 2022-12-08
#
#                 type locations states
# 0   National holiday       All    All
# 1   National holiday       All    All
# 2   National holiday       All    All
# 4   National holiday       All    All
# 10  National holiday       All    All
# 16  National holiday       All    All
# 18  National holiday       All    All
# 19  National holiday       All    All
# 21  National holiday       All    All
# 22  National holiday       All    All
# 24  National holiday       All    All
# 27  National holiday       All    All
# 34  National holiday       All    All
# 35  National holiday       All    All
# 36  National holiday       All    All
# 37  National holiday       All    All
# 38  National holiday       All    All
# 42  National holiday       All    All
# 43  National holiday       All    All
# 44  National holiday       All    All
# 46  National holiday       All    All
# 47  National holiday       All    All
# 58  National holiday       All    All
# 60  National holiday       All    All
# 61  National holiday       All    All
# 62  National holiday       All    All
# 64  National holiday       All    All
# 67  National holiday       All    All
# 74  National holiday       All    All
# 75  National holiday       All    All
# 76  National holiday       All    All

# %%
a_date = df_test.loc[76, 'date']

# %%
td = a_date - pd.Timestamp(today)
td.days
# Out:
# 486

# %%
df_test['days_left'] = df_test['date'].apply(lambda date_value: (date_value - pd.Timestamp(today)).days)

# %%
df_test
# Out:
#     index                                name  \
# 0       0                      New Year's Day
# 1       1            Carnival / Shrove Monday
# 2       2           Carnival / Shrove Tuesday
# 3       3                       March Equinox
# 4       4                        Memorial Day
# ..    ...                                 ...
# 75     33            National Sovereignty Day
# 76     34  Feast of the Immaculate Conception
# 77     35                   December Solstice
# 78     36                       Christmas Day
# 79     37                      New Year's Eve
#
#                                           description    country       date  \
# 0   New Year’s Day is the first day of the year, o...  Argentina 2021-01-01
# 1   Carnival / Shrove Monday is a national holiday...  Argentina 2021-02-15
# 2   Shrove Tuesday is a religious holiday that is ...  Argentina 2021-02-16
# 3           March Equinox in Argentina (Buenos Aires)  Argentina 2021-03-20
# 4     Memorial Day is a national holiday in Argentina  Argentina 2021-03-24
# ..                                                ...        ...        ...
# 75  National Sovereignty Day is a national holiday...  Argentina 2022-11-21
# 76  The Feast of the Immaculate Conception is a Ch...  Argentina 2022-12-08
# 77      December Solstice in Argentina (Buenos Aires)  Argentina 2022-12-21
# 78  Christmas Day is one of the biggest Christian ...  Argentina 2022-12-25
# 79  New Year’s Eve is the last day of the year, De...  Argentina 2022-12-31
#
#                           type locations states  days_left
# 0             National holiday       All    All       -220
# 1             National holiday       All    All       -175
# 2             National holiday       All    All       -174
# 3                       Season       All    All       -142
# 4             National holiday       All    All       -138
# ..                         ...       ...    ...        ...
# 75            National holiday       All    All        469
# 76            National holiday       All    All        486
# 77                      Season       All    All        499
# 78  National holiday,Christian       All    All        503
# 79                  Observance       All    All        509
#
# [80 rows x 9 columns]

# %%
df_test.loc[df_test['days_left'] > 0, : ]
# Out:
#     index                                               name  \
# 26     26                                  Muharram/New Year
# 27     27                                     San Martín Day
# 28     28                                   Rosh Hashana Eve
# 29     29                                       Rosh Hashana
# 30     30                         Second day of Rosh Hashana
# 31     31                                     Yom Kippur Eve
# 32     32                                         Yom Kippur
# 33     33                                  September Equinox
# 34     34                              Bridge Public Holiday
# 35     35              Day of respect for cultural diversity
# 36     36                           National Sovereignty Day
# 37     37                              Bridge Public Holiday
# 38     38                 Feast of the Immaculate Conception
# 39     39                                  December Solstice
# 40     40                                      Christmas Day
# 41     41                                     New Year's Eve
# 42      0                                     New Year's Day
# 43      1                           Carnival / Shrove Monday
# 44      2                          Carnival / Shrove Tuesday
# 45      3                                      March Equinox
# 46      4                                       Memorial Day
# 47      5                                Day of the Veterans
# 48      6                                    Maundy Thursday
# 49      7                                        Good Friday
# 50      8                                       Passover Eve
# 51      9                              First day of Passover
# 52     10                                      Easter Sunday
# 53     11                             Second Day of Passover
# 54     12                              Sixth Day of Passover
# 55     13                            Seventh Day of Passover
# 56     14                               Last day of Passover
# 57     15  Action Day for Tolerance and Respect between P...
# 58     16                                Labor Day / May Day
# 59     17                                     End of Ramadan
# 60     18                   National Day/May 1810 Revolution
# 61     19  Commemoration of General Don Martín Miguel de ...
# 62     20                                           Flag Day
# 63     21                                      June Solstice
# 64     22                                   Independence day
# 65     23                                        Eid al-Adha
# 66     24                                  Muharram/New Year
# 67     25                                     San Martín Day
# 68     26                                  September Equinox
# 69     27                                   Rosh Hashana Eve
# 70     28                                       Rosh Hashana
# 71     29                         Second day of Rosh Hashana
# 72     30                                     Yom Kippur Eve
# 73     31                                         Yom Kippur
# 74     32              Day of respect for cultural diversity
# 75     33                           National Sovereignty Day
# 76     34                 Feast of the Immaculate Conception
# 77     35                                  December Solstice
# 78     36                                      Christmas Day
# 79     37                                     New Year's Eve
#
#                                           description    country       date  \
# 26  Muharram/New Year is a Muslim holiday in Argen...  Argentina 2021-08-10
# 27  San Martín Day is a national holiday in Argentina  Argentina 2021-08-16
# 28  Rosh Hashana Eve is a Jewish holiday in Argentina  Argentina 2021-09-06
# 29  Rosh Hashana, commonly known as the Jewish New...  Argentina 2021-09-07
# 30  Second day of Rosh Hashana is a Jewish holiday...  Argentina 2021-09-08
# 31    Yom Kippur Eve is a Jewish holiday in Argentina  Argentina 2021-09-15
# 32  Yom Kippur (Day of Atonement) is an important ...  Argentina 2021-09-16
# 33      September Equinox in Argentina (Buenos Aires)  Argentina 2021-09-22
# 34  Bridge Public Holiday is a national holiday in...  Argentina 2021-10-08
# 35  Day of respect for cultural diversity is a nat...  Argentina 2021-10-11
# 36  National Sovereignty Day is a national holiday...  Argentina 2021-11-20
# 37  Bridge Public Holiday is a national holiday in...  Argentina 2021-11-22
# 38  The Feast of the Immaculate Conception is a Ch...  Argentina 2021-12-08
# 39      December Solstice in Argentina (Buenos Aires)  Argentina 2021-12-21
# 40  Christmas Day is one of the biggest Christian ...  Argentina 2021-12-25
# 41  New Year’s Eve is the last day of the year, De...  Argentina 2021-12-31
# 42  New Year’s Day is the first day of the year, o...  Argentina 2022-01-01
# 43  Carnival / Shrove Monday is a national holiday...  Argentina 2022-02-28
# 44  Shrove Tuesday is a religious holiday that is ...  Argentina 2022-03-01
# 45          March Equinox in Argentina (Buenos Aires)  Argentina 2022-03-20
# 46    Memorial Day is a national holiday in Argentina  Argentina 2022-03-24
# 47  Day of the Veterans is a national holiday in A...  Argentina 2022-04-02
# 48  Maundy Thursday is a Christian observance on t...  Argentina 2022-04-14
# 49  Good Friday is a global Christian observance t...  Argentina 2022-04-15
# 50          Passover Eve is a observance in Argentina  Argentina 2022-04-15
# 51  During Passover, the Jewish people remember th...  Argentina 2022-04-16
# 52  Easter Sunday commemorates Jesus Christ’s resu...  Argentina 2022-04-17
# 53  Second Day of Passover is a observance in Arge...  Argentina 2022-04-17
# 54  Sixth Day of Passover is a observance in Argen...  Argentina 2022-04-21
# 55  Seventh Day of Passover is a Jewish holiday in...  Argentina 2022-04-22
# 56  The last day of Passover marks the end of the ...  Argentina 2022-04-23
# 57  Action Day for Tolerance and Respect between P...  Argentina 2022-04-24
# 58  Labor Day, or May Day, is a day off for worker...  Argentina 2022-05-01
# 59  Eid-al-Fitr is a holiday to mark the end of th...  Argentina 2022-05-02
# 60  National Day/May 1810 Revolution is a national...  Argentina 2022-05-25
# 61  Commemoration of General Don Martín Miguel de ...  Argentina 2022-06-17
# 62        Flag Day is a national holiday in Argentina  Argentina 2022-06-20
# 63          June Solstice in Argentina (Buenos Aires)  Argentina 2022-06-21
# 64  Independence day is a national holiday in Arge...  Argentina 2022-07-09
# 65  Eid al-Adha (Id ul-Adha) is an Islamic festiva...  Argentina 2022-07-10
# 66  Muharram/New Year is a Muslim holiday in Argen...  Argentina 2022-07-30
# 67  San Martín Day is a national holiday in Argentina  Argentina 2022-08-15
# 68      September Equinox in Argentina (Buenos Aires)  Argentina 2022-09-22
# 69  Rosh Hashana Eve is a Jewish holiday in Argentina  Argentina 2022-09-25
# 70  Rosh Hashana, commonly known as the Jewish New...  Argentina 2022-09-26
# 71  Second day of Rosh Hashana is a Jewish holiday...  Argentina 2022-09-27
# 72    Yom Kippur Eve is a Jewish holiday in Argentina  Argentina 2022-10-04
# 73  Yom Kippur (Day of Atonement) is an important ...  Argentina 2022-10-05
# 74  Day of respect for cultural diversity is a nat...  Argentina 2022-10-10
# 75  National Sovereignty Day is a national holiday...  Argentina 2022-11-21
# 76  The Feast of the Immaculate Conception is a Ch...  Argentina 2022-12-08
# 77      December Solstice in Argentina (Buenos Aires)  Argentina 2022-12-21
# 78  Christmas Day is one of the biggest Christian ...  Argentina 2022-12-25
# 79  New Year’s Eve is the last day of the year, De...  Argentina 2022-12-31
#
#                           type locations states  days_left
# 26     Muslim,Optional holiday       All    All          1
# 27            National holiday       All    All          7
# 28                      Hebrew       All    All         28
# 29     Hebrew,Optional holiday       All    All         29
# 30     Hebrew,Optional holiday       All    All         30
# 31                      Hebrew       All    All         37
# 32     Hebrew,Optional holiday       All    All         38
# 33                      Season       All    All         44
# 34            National holiday       All    All         60
# 35            National holiday       All    All         63
# 36            National holiday       All    All        103
# 37            National holiday       All    All        105
# 38            National holiday       All    All        121
# 39                      Season       All    All        134
# 40  National holiday,Christian       All    All        138
# 41                  Observance       All    All        144
# 42            National holiday       All    All        145
# 43            National holiday       All    All        203
# 44            National holiday       All    All        204
# 45                      Season       All    All        223
# 46            National holiday       All    All        227
# 47            National holiday       All    All        236
# 48  National holiday,Christian       All    All        248
# 49  National holiday,Christian       All    All        249
# 50                  Observance       All    All        249
# 51            Optional holiday       All    All        250
# 52        Observance,Christian       All    All        251
# 53            Optional holiday       All    All        251
# 54                  Observance       All    All        255
# 55     Hebrew,Optional holiday       All    All        256
# 56     Hebrew,Optional holiday       All    All        257
# 57                  Observance       All    All        258
# 58            National holiday       All    All        265
# 59     Muslim,Optional holiday       All    All        266
# 60            National holiday       All    All        289
# 61            National holiday       All    All        312
# 62            National holiday       All    All        315
# 63                      Season       All    All        316
# 64            National holiday       All    All        334
# 65     Muslim,Optional holiday       All    All        335
# 66     Muslim,Optional holiday       All    All        355
# 67            National holiday       All    All        371
# 68                      Season       All    All        409
# 69                      Hebrew       All    All        412
# 70     Hebrew,Optional holiday       All    All        413
# 71     Hebrew,Optional holiday       All    All        414
# 72                      Hebrew       All    All        421
# 73     Hebrew,Optional holiday       All    All        422
# 74            National holiday       All    All        427
# 75            National holiday       All    All        469
# 76            National holiday       All    All        486
# 77                      Season       All    All        499
# 78  National holiday,Christian       All    All        503
# 79                  Observance       All    All        509

# %%
df.to_csv('holidays_download.csv', encoding='utf-8-sig', sep='|')

# %%
df_new = ('holidays_download.csv', sep='|')
# Out:
#   File "<ipython-input-27-83db1c01135c>", line 1
#     df_new = ('holidays_download.csv', sep='|')
#                                           ^
# SyntaxError: invalid syntax
