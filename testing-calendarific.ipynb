# %%
import pandas as pd
import requests
import json

# %%
country = 'AR'
year = '2021'

response = requests.get(f'https://calendarific.com/api/v2/holidays?&api_key=87d04b7e567fbef95171bbde43d3c320c6cbc2e2&country={country}&year={year}')
data = json.loads(response.text)

# %%
data
# Out:
# {'meta': {'code': 200},
#  'response': {'holidays': [{'name': "New Year's Day",
#     'description': 'New Year’s Day is the first day of the year, or January 1, in the Gregorian calendar.',
#     'country': {'id': 'ar', 'name': 'Argentina'},
#     'date': {'iso': '2021-01-01',
#      'datetime': {'year': 2021, 'month': 1, 'day': 1}},
#     'type': ['National holiday'],
#     'locations': 'All',
#     'states': 'All'},
#    {'name': 'Carnival / Shrove Monday',
#     'description': 'Carnival / Shrove Monday is a national holiday in Argentina',
#     'country': {'id': 'ar', 'name': 'Argentina'},
#     'date': {'iso': '2021-02-15',
#      'datetime': {'year': 2021, 'month': 2, 'day': 15}},
#     'type': ['National holiday'],
#     'locations': 'All',
#     'states': 'All'},
#    {'name': 'Carnival / Shrove Tuesday',
# ...

# %%
clean_data = data['response']['holidays']

# %%
df = pd.DataFrame.from_dict(clean_data)

# %%
df
# Out:
#                                                  name  \
# 0                                      New Year's Day
# 1                            Carnival / Shrove Monday
# 2                           Carnival / Shrove Tuesday
# 3                                       March Equinox
# 4                                        Memorial Day
# 5                                        Passover Eve
# 6                               First day of Passover
# 7                              Second Day of Passover
# 8                                     Maundy Thursday
# 9                                         Good Friday
# 10                                Day of the Veterans
# 11                              Sixth Day of Passover
# 12                            Seventh Day of Passover
# 13                                      Easter Sunday
# 14                               Last day of Passover
# 15  Action Day for Tolerance and Respect between P...
# ...
